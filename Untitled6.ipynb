# %%
# !pip install -q earthengine-api geemap ruptures pymannkendall prophet statsmodels folium geopandas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 51.9 MB/s eta 0:00:00

# %%
import ee
ee.Authenticate()
ee.Initialize(project='gen-lang-client-0174302125')   # <-- replace with your GCP project ID

# %%
import geemap
import geopandas as gpd

CITY_NAME = "Chennai"
CITY_LAT, CITY_LON = 13.0827, 80.2707

# Option A: upload your own ward geojson to Colab's file panel, then:
USE_WARDS = False   # set True once you upload a real ward file
if USE_WARDS:
    wards = gpd.read_file('/content/wards.geojson')   # must have 'ward_name' column
else:
    # Option B: fallback fishnet grid (~1km cells) over a 15km box around the city center
    import numpy as np
    from shapely.geometry import box
    deg = 0.01  # ~1.1km
    half_span = 0.15  # ~15km each side
    cells = []
    ward_id = 0
    for x in np.arange(CITY_LON - half_span, CITY_LON + half_span, deg):
        for y in np.arange(CITY_LAT - half_span, CITY_LAT + half_span, deg):
            cells.append({'ward_name': f'Cell_{ward_id}', 'geometry': box(x, y, x+deg, y+deg)})
            ward_id += 1
    wards = gpd.GeoDataFrame(cells, crs='EPSG:4326')

wards_ee = geemap.geopandas_to_ee(wards)
aoi = wards_ee.geometry()
print(f"{len(wards)} zones defined.")
# Out:
# 961 zones defined.

# %%
START_YEAR, END_YEAR = 2015, 2024

def mask_s2(img):
    scl = img.select('SCL')
    mask = scl.neq(3).And(scl.neq(8)).And(scl.neq(9)).And(scl.neq(10))
    return img.updateMask(mask).divide(10000)

def mask_l8(img):
    qa = img.select('QA_PIXEL')
    cloud_mask = qa.bitwiseAnd(1 << 3).eq(0).And(qa.bitwiseAnd(1 << 4).eq(0))
    return img.updateMask(cloud_mask)

def get_annual_composite(year, aoi):
    start, end = f'{year}-01-01', f'{year}-12-31'
    s2 = (ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
          .filterDate(start, end).filterBounds(aoi)
          .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 30))
          .map(mask_s2).median())
    l8 = (ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')
          .filterDate(start, end).filterBounds(aoi)
          .map(mask_l8).median())
    lst = l8.select('ST_B10').multiply(0.00341802).add(149.0).subtract(273.15).rename('LST')
    ndvi = s2.normalizedDifference(['B8', 'B4']).rename('NDVI')
    ndbi = s2.normalizedDifference(['B11', 'B8']).rename('NDBI')
    return ee.Image.cat([ndvi, ndbi, lst]).set('year', year)

print("Functions ready.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Functions ready.

# %%
import pandas as pd
import time

records = []
for year in range(START_YEAR, END_YEAR + 1):
    img = get_annual_composite(year, aoi)
    try:
        stats = img.reduceRegions(collection=wards_ee, reducer=ee.Reducer.mean(), scale=100).getInfo()
        for f in stats['features']:
            p = f['properties']
            records.append({'ward': p.get('ward_name'), 'year': year,
                             'NDVI': p.get('NDVI'), 'NDBI': p.get('NDBI'), 'LST': p.get('LST')})
        print(f"Year {year} done.")
    except Exception as e:
        print(f"Year {year} failed: {e}")
    time.sleep(1)

df = pd.DataFrame(records)
df.to_csv('/content/ward_timeseries.csv', index=False)
df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Year 2015 failed: Image.normalizedDifference: No band named 'B8'. Available band names: [].
# Year 2016 done.
# Year 2017 done.
# Year 2018 done.
# Year 2019 done.
# Year 2020 done.
# Year 2021 done.
# Year 2022 done.
# Year 2023 done.
# Year 2024 done.
#      ward  year      NDVI      NDBI        LST
# 0  Cell_0  2016  0.416742 -0.031829  38.246738
# 1  Cell_1  2016  0.418622 -0.050266  37.386811
# 2  Cell_2  2016  0.279368 -0.038471  37.353933
# 3  Cell_3  2016  0.285569  0.039643  40.318856
# 4  Cell_4  2016  0.291356  0.038067  42.054582

# %%
def get_rainfall(year, aoi):
    return (ee.ImageCollection('UCSB-CHG/CHIRPS/DAILY')
            .filterDate(f'{year}-01-01', f'{year}-12-31').filterBounds(aoi)
            .sum().rename('RAINFALL').set('year', year))

rain_records = []
for year in range(START_YEAR, END_YEAR + 1):
    img = get_rainfall(year, aoi)
    stats = img.reduceRegions(collection=wards_ee, reducer=ee.Reducer.mean(), scale=5000).getInfo()
    for f in stats['features']:
        rain_records.append({'ward': f['properties'].get('ward_name'), 'year': year,
                              'rainfall': f['properties'].get('mean')})

rain_df = pd.DataFrame(rain_records)
df = df.merge(rain_df, on=['ward', 'year'], how='left')
df.to_csv('/content/ward_timeseries_full.csv', index=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import pymannkendall as mk

trend_results = []
for ward in df['ward'].unique():
    series = df[df['ward'] == ward].sort_values('year')['LST'].dropna()
    if len(series) >= 4:
        result = mk.original_test(series)
        trend_results.append({'ward': ward, 'trend': result.trend, 'p_value': result.p, 'slope': result.slope})

trend_df = pd.DataFrame(trend_results)
trend_df.to_csv('/content/trend_significance.csv', index=False)
trend_df.sort_values('slope', ascending=False).head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#          ward     trend   p_value     slope
# 331  Cell_331  no trend  0.465512  0.363843
# 460  Cell_460  no trend  0.175308  0.322159
# 428  Cell_428  no trend  0.602168  0.322150
# 265  Cell_265  no trend  0.754454  0.310255
# 554  Cell_554  no trend  0.348083  0.305482
# 490  Cell_490  no trend  0.602168  0.287840
# 74    Cell_74  no trend  0.465512  0.285349
# 300  Cell_300  no trend  0.602168  0.267399
# 268  Cell_268  no trend  0.602168  0.267070
# 101  Cell_101  no trend  0.916965  0.257376

# %%
import ruptures as rpt
import numpy as np

cp_results = []
for ward in df['ward'].unique():
    sub = df[df['ward'] == ward].sort_values('year')
    series = sub['NDVI'].dropna().values
    years = sub['year'].values
    if len(series) >= 5:
        algo = rpt.Pelt(model="rbf").fit(series)
        bkps = algo.predict(pen=3)
        bkp_years = [years[i] for i in bkps if i < len(years)]
        cp_results.append({'ward': ward, 'changepoint_years': bkp_years})

cp_df = pd.DataFrame(cp_results)
cp_df.to_csv('/content/changepoints.csv', index=False)
cp_df.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#      ward changepoint_years
# 0  Cell_0                []
# 1  Cell_1                []
# 2  Cell_2                []
# 3  Cell_3                []
# 4  Cell_4                []
# 5  Cell_5                []
# 6  Cell_6                []
# 7  Cell_7                []
# 8  Cell_8                []
# 9  Cell_9                []

# %%
from sklearn.linear_model import LinearRegression

model_df = df.dropna(subset=['NDVI', 'NDBI', 'rainfall', 'LST'])
X = model_df[['NDVI', 'NDBI', 'rainfall']]
y = model_df['LST']
model = LinearRegression().fit(X, y)

print("Coefficients:", dict(zip(X.columns, model.coef_)))
print("R²:", model.score(X, y))

import json
with open('/content/regression_summary.json', 'w') as f:
    json.dump({'coefficients': dict(zip(X.columns, model.coef_)), 'r2': model.score(X, y)}, f)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Coefficients: {'NDVI': np.float64(12.935665355382213), 'NDBI': np.float64(23.59511131180429), 'rainfall': np.float64(4.4691821528886067e-05)}
# R²: 0.6605685911930131

# %%
import matplotlib.pyplot as plt

top_ward = trend_df.sort_values('slope', ascending=False).iloc[0]['ward']
sub = df[df['ward'] == top_ward].sort_values('year')

fig, ax = plt.subplots(figsize=(8,5))
ax.plot(sub['year'], sub['LST'], marker='o', label='LST (°C)')
ax2 = ax.twinx()
ax2.plot(sub['year'], sub['NDVI'], marker='s', color='green', label='NDVI')
ax.set_xlabel('Year'); ax.set_ylabel('LST (°C)'); ax2.set_ylabel('NDVI')
plt.title(f'LST vs NDVI Trend — {top_ward}')
fig.legend(loc='upper right')
plt.savefig('/content/trend_chart.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import folium

latest = df[df['year'] == END_YEAR]
wards_latest = wards.merge(latest, left_on='ward_name', right_on='ward')

m = folium.Map(location=[CITY_LAT, CITY_LON], zoom_start=11)
folium.Choropleth(
    geo_data=wards_latest.to_json(),
    data=wards_latest,
    columns=['ward_name', 'LST'],
    key_on='feature.properties.ward_name',
    fill_color='YlOrRd',
    legend_name=f'Land Surface Temperature {END_YEAR} (°C)'
).add_to(m)
m.save('/content/heat_risk_map.html')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e7f4689dfe56ddc2932729b2fd1dbce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e7f4689dfe56ddc2932729b2fd1dbce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e7f4689dfe56ddc2932729b2fd1dbce = L.map(
#                 &quot;map_7e7f4689dfe56ddc2932729b2fd1dbce&quot;,
#                 {
#                     center: [13.0827, 80.2707],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1d15a53a50ac7a3f221d436430913e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e1d15a53a50ac7a3f221d436430913e1.addTo(map_7e7f4689dfe56ddc2932729b2fd1dbce);
#
#
#             var choropleth_8ef68719e2632eebf03724d7891bbe49 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_e020af394b2f7fcbcc8b95610a01c87b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;3&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;9&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;24&quot;: case &quot;26&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;40&quot;: case &quot;44&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;49&quot;: case &quot;51&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;70&quot;: case &quot;71&quot;: case &quot;72&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;84&quot;: case &quot;86&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;89&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;96&quot;: case &quot;97&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;106&quot;: case &quot;109&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;126&quot;: case &quot;127&quot;: case &quot;128&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;150&quot;: case &quot;151&quot;: case &quot;152&quot;: case &quot;153&quot;: case &quot;155&quot;: case &quot;157&quot;: case &quot;158&quot;: case &quot;163&quot;: case &quot;164&quot;: case &quot;166&quot;: case &quot;168&quot;: case &quot;169&quot;: case &quot;170&quot;: case &quot;171&quot;: case &quot;172&quot;: case &quot;181&quot;: case &quot;185&quot;: case &quot;186&quot;: case &quot;187&quot;: case &quot;188&quot;: case &quot;189&quot;: case &quot;190&quot;: case &quot;191&quot;: case &quot;192&quot;: case &quot;194&quot;: case &quot;195&quot;: case &quot;196&quot;: case &quot;197&quot;: case &quot;199&quot;: case &quot;200&quot;: case &quot;201&quot;: case &quot;202&quot;: case &quot;203&quot;: case &quot;206&quot;: case &quot;212&quot;: case &quot;218&quot;: case &quot;219&quot;: case &quot;220&quot;: case &quot;221&quot;: case &quot;222&quot;: case &quot;223&quot;: case &quot;224&quot;: case &quot;225&quot;: case &quot;227&quot;: case &quot;228&quot;: case &quot;229&quot;: case &quot;231&quot;: case &quot;232&quot;: case &quot;233&quot;: case &quot;234&quot;: case &quot;235&quot;: case &quot;236&quot;: case &quot;237&quot;: case &quot;238&quot;: case &quot;242&quot;: case &quot;243&quot;: case &quot;244&quot;: case &quot;248&quot;: case &quot;249&quot;: case &quot;250&quot;: case &quot;252&quot;: case &quot;253&quot;: case &quot;254&quot;: case &quot;255&quot;: case &quot;256&quot;: case &quot;257&quot;: case &quot;258&quot;: case &quot;259&quot;: case &quot;260&quot;: case &quot;261&quot;: case &quot;262&quot;: case &quot;264&quot;: case &quot;265&quot;: case &quot;266&quot;: case &quot;267&quot;: case &quot;268&quot;: case &quot;269&quot;: case &quot;272&quot;: case &quot;273&quot;: case &quot;279&quot;: case &quot;281&quot;: case &quot;282&quot;: case &quot;283&quot;: case &quot;284&quot;: case &quot;285&quot;: case &quot;286&quot;:

# %%
# !pip install -q selenium
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
driver = webdriver.Chrome(options=options)
driver.set_window_size(1000, 800)
driver.get('file:///content/heat_risk_map.html')
time.sleep(3)
driver.save_screenshot('/content/heat_risk_map.png')
driver.quit()

# !zip -j /content/uhi_outputs.zip /content/ward_timeseries_full.csv /content/trend_significance.csv /content/changepoints.csv /content/regression_summary.json /content/trend_chart.png /content/heat_risk_map.png
from google.colab import files
files.download('/content/uhi_outputs.zip')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 91.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 kB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 7.3 MB/s eta 0:00:00
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# /tmp/ipykernel_2416/601401677.py in <cell line: 0>()
#       7 options.add_argument('--headless')
#       8 options.add_argument('--no-sandbox')
# ----> 9 driver = webdriver.Chrome(options=options)
#      10 driver.set_window_size(1000, 800)
#      11 driver.get('file:///content/heat_risk_map.html')
#
# /usr/local/lib/python3.13/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.13/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      64
#      65         try:
# ---> 66             super().__init__(command_executor=executor, options=self.options)
#      67         except Exception:
#      68             self.quit()
#
# /usr/local/lib/python3.13/dist-packages/selenium/webdriver/common/webdriver.py in __init__(self, *args, **kwargs)
#      23
#      24     def __init__(self, *args, **kwargs):
# ---> 25         super().__init__(*args, **kwargs)
#      26         self._is_remote = False
#      27
#
# /usr/local/lib/python3.13/dist-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     294         self._authenticator_id = None
#     295         self.start_client()
# --> 296         self.start_session(capabilities)
#     297         self._fedcm = FedCM(self)
#     298
#
# /usr/local/lib/python3.13/dist-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities)
#     399             caps = _create_caps(capabilities)
#     400         try:
# --> 401             response = self.execute(Command.NEW_SESSION, caps)["value"]
#     402             self.session_id = response.get("sessionId")
#     403             self.caps = response.get("capabilities")
#
# /usr/local/lib/python3.13/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     504
#     505         if response:
# --> 506             self.error_handler.check_response(response)
#     507             response["value"] = self._unwrap_value(response.get("value", None))
#     508             return response
#
# /usr/local/lib/python3.13/dist-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     230                 alert_text = value["alert"].get("text")
#     231             raise exception_class(message, screen, stacktrace, alert_text)
# --> 232         raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: Chrome instance exited. Examine ChromeDriver verbose log to determine the cause.; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#sessionnotcreatedexception
# Stacktrace:
# #0 0x5abd3996687a <unknown>
# #1 0x5abd39298b99 <unknown>
# #2 0x5abd392d811e <unknown>
# #3 0x5abd392d3a0f <unknown>
# #4 0x5abd39323fde <unknown>
# #5 0x5abd3932369c <unknown>
# #6 0x5abd392e217b <unknown>
# #7 0x5abd392e2f61 <unknown>
# #8 0x5abd39929247 <unknown>
# #9 0x5abd39927a75 <unknown>
# #10 0x5abd39912b35 <unknown>
# #11 0x5abd399286ca <unknown>
# #12 0x5abd398fb219 <unknown>
# #13 0x5abd39950698 <unknown>
# #14 0x5abd39950835 <unknown>
# #15 0x5abd399651c3 <unknown>
# #16 0x78d2158deb84 <unknown>
# #17 0x78d21596bd6c <unknown>
